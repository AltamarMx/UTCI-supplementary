# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse
from numpy.linalg import lstsq
import numpy as np
from matplotlib import gridspec
import string

# %%
f = "../data/demanda_utci_regions.parquet"
data = pd.read_parquet(f)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 63432 entries, 2016-01-27 00:00:00 to 2023-04-22 23:00:00
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PEN_DEMANDA  63329 non-null  float64
#  1   BC_DEMANDA   63400 non-null  float64
#  2   CEN_DEMANDA  63329 non-null  float64
#  3   N_DEMANDA    63329 non-null  float64
#  4   NE_DEMANDA   63329 non-null  float64
#  5   NO_DEMANDA   63329 non-null  float64
#  6   OCC_DEMANDA  63329 non-null  float64
#  7   ORI_DEMANDA  63329 non-null  float64
#  8   BCS_DEMANDA  62033 non-null  float64
#  9   BC_UTCI      63424 non-null  float32
#  10  BCS_UTCI     63432 non-null  float32
#  11  CEN_UTCI     63425 non-null  float32
#  12  N_UTCI       63425 non-null  float32
#  13  NE_UTCI      63425 non-null  float32
#  14  NO_UTCI      63425 non-null  float32
#  15  OCC_UTCI     63425 non-null  float32
#  16  ORI_UTCI     63425 non-null  float32
# ...

# %%
# --- Tus helpers (los dejo tal cual) ---
def _fit_harmonic(df, ycol, periodo_h, n_harmonics=1):
    s = df[ycol].dropna()
    if s.empty:
        raise ValueError("Serie vacía tras dropna().")
    t0 = s.index[0]
    t_h = (s.index - t0).total_seconds() / 3600.0
    y   = s.values.astype(float)
    ω = 2.0*np.pi/periodo_h
    cols = [np.ones_like(t_h)]
    for k in range(1, n_harmonics+1):
        cols.append(np.cos(k*ω*t_h))
        cols.append(np.sin(k*ω*t_h))
    X = np.column_stack(cols)
    beta, *_ = np.linalg.lstsq(X, y, rcond=None)
    return beta, t0

def _predict_harmonic(beta, t_h, periodo_h, n_harmonics=1):
    ω = 2.0*np.pi/periodo_h
    cols = [np.ones_like(t_h)]
    for k in range(1, n_harmonics+1):
        cols.append(np.cos(k*ω*t_h))
        cols.append(np.sin(k*ω*t_h))
    X = np.column_stack(cols)
    return X @ beta

def ciclo_promedio(df, ycol, periodo_h):
    s = df[ycol].dropna()
    t_h = (s.index - s.index[0]).total_seconds()/3600.0
    P = int(periodo_h)
    fase_h = np.rint(t_h % P).astype(int) % P
    g = pd.Series(s.values, index=fase_h).groupby(level=0).mean()
    m = g.reindex(range(P)).interpolate(limit_direction="both")
    return m, fase_h  # índice 0..P-1

# --- Nueva función con 5 paneles: 1 arriba + 2x2 abajo ---
def plot_anual_y_grid(df, ycol,
                      periodos_grid=[168, 84, 24, 12],
                      titulos_grid=[r"$\tau = 7$ days", r"$\tau = 3.5$ days",
                                    r"$\tau = 1$ day", r"$\tau = 12$ hours"],
                      periodo_anual_h=8760,  # usa 8760=365*24
                      titulo_anual=r"$\tau \approx 1$ year",
                      n_harmonics=1):
    """
    Disposición:
      ┌───────────────────────────────┐  <- Anual (ancho)
      ├───────────────┬───────────────┤
      │   7 días      │   3.5 días    │
      ├───────────────┼───────────────┤
      │   1 día       │   12 horas    │
      └───────────────┴───────────────┘
    """
    s = df[ycol].dropna()
    if s.empty:
        raise ValueError("Serie vacía tras dropna().")
    anchor = s.index[0].floor("h")

    # Layout con GridSpec: fila superior más alta
    fig = plt.figure(figsize=(12, 9))
    gs  = gridspec.GridSpec(3, 2, height_ratios=[1.2, 1, 1], hspace=0.35, wspace=0.25)

    # ---------- Panel superior: ANUAL ----------
    ax_top = fig.add_subplot(gs[0, :])

    # Ciclo promedio anual (1×τ para mejor legibilidad)
    P_y = int(periodo_anual_h)
    m_y, _ = ciclo_promedio(df, ycol, P_y)      # 0..P_y-1
    x1 = np.arange(P_y, dtype=float)
    y1 = m_y.values

    # Armónico anual
    beta_y, _ = _fit_harmonic(df, ycol, P_y, n_harmonics=n_harmonics)
    y1_fit = _predict_harmonic(beta_y, x1, P_y, n_harmonics=n_harmonics)

    # Dibujar
    ax_top.plot(x1, y1, lw=1.2, label="Mean cycle")
    ax_top.plot(x1, y1_fit, lw=1.4, linestyle="-.", label="$\\tau = 1$ year ")
    ax_top.set_xlim(0, P_y)

    # Ticks trimestrales (0, 1/4τ, 1/2τ, 3/4τ, τ)
    q_ticks = [0, P_y//4, P_y//2, 3*P_y//4, P_y]
    ax_top.set_xticks(q_ticks)
    dticks = [anchor + pd.Timedelta(hours=int(k)) for k in q_ticks]
    ax_top.set_xticklabels([d.strftime("%Y-%m-%d") for d in dticks])
    ax_top.grid(axis="x", which="major", linestyle="--")
    # ax_top.set_title(titulo_anual)
    ax_top.set_ylabel("Demand [MWh]")
    ax_top.legend(loc="best")

    # ---------- Cuadrícula inferior 2×2 ----------
    axes_grid = []
    pos = [(1,0), (1,1), (2,0), (2,1)]
    for (r,c), P, titulo in zip(pos, periodos_grid, titulos_grid):
        ax = fig.add_subplot(gs[r, c])
        axes_grid.append(ax)

        # Ciclo promedio por fase
        m, _ = ciclo_promedio(df, ycol, P)
        y3 = np.tile(m.values, 3)
        x3 = np.arange(3*int(P), dtype=float)

        # Ajuste armónico
        beta, _ = _fit_harmonic(df, ycol, P, n_harmonics=n_harmonics)
        y_fit = _predict_harmonic(beta, x3, P, n_harmonics=n_harmonics)

        ax.plot(x3, y3, lw=1.2, label="Mean cycle (3×τ)")
        ax.plot(x3, y_fit, lw=1.4, linestyle="-.", label=f"{titulo}")

        ax.set_xlim(0, 3*int(P))
        ticks = [0, int(P), 2*int(P), 3*int(P)]
        ax.set_xticks(ticks)
        
        # for s in ["top", "right"]:
        #     ax.spines[s].set_visible(False)

        dticks = [anchor + pd.Timedelta(hours=int(k*P)) for k in range(4)]
        if (P % 24) == 0:
            labels = [d.strftime("%Y-%m-%d") for d in dticks]
        else:
            labels = [d.strftime("%Y-%m-%d\n%H:%M") for d in dticks]
        ax.set_xticklabels(labels)
        ax.grid(axis="x", which="major", linestyle="--")

        # ax.set_title(titulo)
        ax.set_ylabel("Demand [MWh]")
        ax.legend(loc="best")

    # fig.tight_layout()
    return fig, ax_top,ax


 
periodos_grid = [168, 84, 24, 12]
titulos_grid  = [r"$\tau = 7$ days", r"$\tau = 3.5$ days",
                 r"$\tau = 1$ day", r"$\tau = 12$ hours"]

fig, axes,_ = plot_anual_y_grid(
    data, "N_DEMANDA",
    periodos_grid=periodos_grid,
    titulos_grid=titulos_grid,
    periodo_anual_h=8760,     # si prefieres 365.25 días, redondea a 8766
    titulo_anual=r"$\tau \approx 1$ year",
    n_harmonics=1             # sube a 2 si la forma no es sinusoidal
)
plt.show()

# %%
# --- Tus helpers (idénticos) ---
def _fit_harmonic(df, ycol, periodo_h, n_harmonics=1):
    s = df[ycol].dropna()
    if s.empty:
        raise ValueError("Serie vacía tras dropna().")
    t0 = s.index[0]
    t_h = (s.index - t0).total_seconds() / 3600.0
    y   = s.values.astype(float)
    ω = 2.0*np.pi/periodo_h
    cols = [np.ones_like(t_h)]
    for k in range(1, n_harmonics+1):
        cols.append(np.cos(k*ω*t_h))
        cols.append(np.sin(k*ω*t_h))
    X = np.column_stack(cols)
    beta, *_ = np.linalg.lstsq(X, y, rcond=None)
    return beta, t0

def _predict_harmonic(beta, t_h, periodo_h, n_harmonics=1):
    ω = 2.0*np.pi/periodo_h
    cols = [np.ones_like(t_h)]
    for k in range(1, n_harmonics+1):
        cols.append(np.cos(k*ω*t_h))
        cols.append(np.sin(k*ω*t_h))
    X = np.column_stack(cols)
    return X @ beta

def ciclo_promedio(df, ycol, periodo_h):
    s = df[ycol].dropna()
    t_h = (s.index - s.index[0]).total_seconds()/3600.0
    P = int(periodo_h)
    fase_h = np.rint(t_h % P).astype(int) % P
    g = pd.Series(s.values, index=fase_h).groupby(level=0).mean()
    m = g.reindex(range(P)).interpolate(limit_direction="both")
    return m, fase_h  # índice 0..P-1

# --- Nueva función con 5 paneles y letras a) b) c) d) e) en bbox ---
def plot_anual_y_grid(
    df, ycol,
    periodos_grid=[168, 84, 24, 12],
    titulos_grid=[r"$\tau = 7$ days", r"$\tau = 3.5$ days", r"$\tau = 1$ day", r"$\tau = 12$ hours"],
    periodo_anual_h=8760,                  # 365*24
    titulo_anual=r"$\tau \approx 1$ year",
    n_harmonics=1,
    panel_labels=None                      # si None, autogenera a), b), c)...
):
    """
    Disposición:
      ┌───────────────────────────────┐  <- Anual (ancho)   a)
      ├───────────────┬───────────────┤
      │   7 días      │   3.5 días    │   b)  c)
      ├───────────────┼───────────────┤
      │   1 día       │   12 horas    │   d)  e)
      └───────────────┴───────────────┘
    """
    s = df[ycol].dropna()
    if s.empty:
        raise ValueError("Serie vacía tras dropna().")
    anchor = s.index[0].floor("h")

    # Layout con GridSpec: fila superior más alta
    fig = plt.figure(figsize=(12, 9))
    gs  = gridspec.GridSpec(3, 2, height_ratios=[1.2, 1, 1], hspace=0.35, wspace=0.25)

    # ---------- Panel superior: ANUAL ----------
    ax_top = fig.add_subplot(gs[0, :])

    # Ciclo promedio anual
    P_y = int(periodo_anual_h)
    m_y, _ = ciclo_promedio(df, ycol, P_y)      # 0..P_y-1
    x1 = np.arange(P_y, dtype=float)
    y1 = m_y.values

    # Armónico anual
    beta_y, _ = _fit_harmonic(df, ycol, P_y, n_harmonics=n_harmonics)
    y1_fit = _predict_harmonic(beta_y, x1, P_y, n_harmonics=n_harmonics)

    ax_top.plot(x1, y1, lw=1.2, label="Mean cycle")
    ax_top.plot(x1, y1_fit, lw=1.4, linestyle="-.", label="$\\tau = 1$ year ")
    ax_top.set_xlim(0, P_y)

    # Ticks trimestrales (0, 1/4τ, 1/2τ, 3/4τ, τ)
    q_ticks = [0, P_y//4, P_y//2, 3*P_y//4, P_y]
    ax_top.set_xticks(q_ticks)
    dticks = [anchor + pd.Timedelta(hours=int(k)) for k in q_ticks]
    ax_top.set_xticklabels([d.strftime("%Y-%m-%d") for d in dticks])
    ax_top.grid(axis="x", which="major", linestyle="--")
    ax_top.set_ylabel("Demand [MWh]")
    ax_top.legend(loc="best")

    # ---------- Cuadrícula inferior 2×2 ----------
    axes_grid = []
    pos = [(1,0), (1,1), (2,0), (2,1)]
    for (r,c), P, titulo in zip(pos, periodos_grid, titulos_grid):
        ax = fig.add_subplot(gs[r, c])
        axes_grid.append(ax)

        # Ciclo promedio por fase
        m, _ = ciclo_promedio(df, ycol, P)
        y3 = np.tile(m.values, 3)
        x3 = np.arange(3*int(P), dtype=float)

        # Ajuste armónico
        beta, _ = _fit_harmonic(df, ycol, P, n_harmonics=n_harmonics)
        y_fit = _predict_harmonic(beta, x3, P, n_harmonics=n_harmonics)

        ax.plot(x3, y3, lw=1.2, label="Mean cycle (3×τ)")
        ax.plot(x3, y_fit, lw=1.4, linestyle="-.", label=f"{titulo}")

        ax.set_xlim(0, 3*int(P))
        ticks = [0, int(P), 2*int(P), 3*int(P)]
        ax.set_xticks(ticks)

        dticks = [anchor + pd.Timedelta(hours=int(k*P)) for k in range(4)]
        if (P % 24) == 0:
            labels = [d.strftime("%Y-%m-%d") for d in dticks]
        else:
            labels = [d.strftime("%Y-%m-%d\n%H:%M") for d in dticks]
        ax.set_xticklabels(labels)
        ax.grid(axis="x", which="major", linestyle="--")
        ax.set_ylabel("Demand [MWh]")
        ax.legend(loc="best")

    # ---------- Letras a) b) c) d) e) en bbox (sin bold) ----------
    axes_all = [ax_top] + axes_grid
    if panel_labels is None:
        panel_labels = [f"{string.ascii_lowercase[i]})" for i in range(len(axes_all))]
    for ax, lab in zip(axes_all, panel_labels):
        ax.text(
            0.015, 0.98, lab,
            transform=ax.transAxes, ha="left", va="top",
            fontsize=12,
            bbox=dict(facecolor="white", edgecolor="gray", linewidth=0.6, alpha=0.9, boxstyle="round,pad=0.2"),
            zorder=10
        )

    # Devuelve igual que antes para no romper llamadas previas
    return fig, axes_all, axes_grid[-1]

# ----------- Ejemplo de uso -----------
periodos_grid = [168, 84, 24, 12]
titulos_grid  = [r"$\tau = 7$ days", r"$\tau = 3.5$ days",
                 r"$\tau = 1$ day", r"$\tau = 12$ hours"]

fig, axes, _ = plot_anual_y_grid(
    data, "N_DEMANDA",
    periodos_grid=periodos_grid,
    titulos_grid=titulos_grid,
    periodo_anual_h=8760,
    titulo_anual=r"$\tau \approx 1$ year",
    n_harmonics=1,
    panel_labels=["a)", "b)", "c)", "d)", "e)"]  # opcional
)
plt.show()

fig.savefig("fit_frequencies.png")
